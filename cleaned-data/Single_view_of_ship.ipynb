# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv('/home/kiran/Downloads/cleaned-data/Raw-Data/Single_view_of_ship.csv')

# %%
data
# Out:
#            Name of Ship First Event of Ship Last Event of Ship  \
# 0             ACE SPAIN          2014-12-28         2017-03-06
# 1                ADITYA          2015-09-08         2020-05-23
# 2     AFRICAN SPOONBILL          2016-11-21         2019-12-29
# 3        AFRICAN TURACO          2016-03-19         2019-12-12
# 4          AL-BETROLEYA          2016-01-03         2020-05-19
# ..                  ...                 ...                ...
# 324  X-PRESS MONTE ROSA          2015-07-03         2015-07-07
# 325   X-PRESS TAJUMULCO          2015-11-01         2017-03-12
# 326     X-PRESS VESUVIO          2015-07-19         2017-01-27
# 327            YERUPAJA          2015-06-30         2017-02-27
# 328                ZOLA          2020-03-21         2020-05-10
#
#      Life time of Ship in months  recency of First Event  \
# 0                      26.251052               18.825849
# 1                      56.477546               27.170989
# ...

# %%
data.columns
# Out:
# Index(['Name of Ship', 'First Event of Ship', 'Last Event of Ship',
#        'Life time of Ship in months', 'recency of First Event',
#        'recency of Last Event', 'nLARP-Total', 'nLARP_Closure',
#        'nLARP_Status_Accepted', 'nLARP_Status_Open', 'nLARP_Status_Rejected',
#        'nLARP_Category_Safe act', 'nLARP_Category_Unsafe act',
#        'mLARP_Accepted-Safe act', 'mLARP_Accepted-Safe act-Closure',
#        'mLARP_Accepted-Unsafe act', 'mLARP_Accepted-Unsafe act-Closure',
#        'mLARP_Open-Safe act', 'mLARP_Open-Unsafe act',
#        'mLARP_Rejected-Safe act', 'mLARP_Rejected-Safe act-Closure',
#        'mLARP_Rejected-Unsafe act', 'mLARP_Rejected-Unsafe act-Closure',
#        'nNM-Total', 'nNM_Near Miss', 'nNM_Report',
#        'nNM_Investigation Commenced', 'nNM_Investigation Completion',
#        'nNM_Closure', 'nNM_Severity of incident_High',
#        'nNM_Severity of incident_Low', 'nNM_Severity of incident_Medium',
#        'nNM_Severity of incident_Unknown',
# ...

# %%
data.columns = data.columns.str.lower()

# %%
data.columns
# Out:
# Index(['name of ship', 'first event of ship', 'last event of ship',
#        'life time of ship in months', 'recency of first event',
#        'recency of last event', 'nlarp-total', 'nlarp_closure',
#        'nlarp_status_accepted', 'nlarp_status_open', 'nlarp_status_rejected',
#        'nlarp_category_safe act', 'nlarp_category_unsafe act',
#        'mlarp_accepted-safe act', 'mlarp_accepted-safe act-closure',
#        'mlarp_accepted-unsafe act', 'mlarp_accepted-unsafe act-closure',
#        'mlarp_open-safe act', 'mlarp_open-unsafe act',
#        'mlarp_rejected-safe act', 'mlarp_rejected-safe act-closure',
#        'mlarp_rejected-unsafe act', 'mlarp_rejected-unsafe act-closure',
#        'nnm-total', 'nnm_near miss', 'nnm_report',
#        'nnm_investigation commenced', 'nnm_investigation completion',
#        'nnm_closure', 'nnm_severity of incident_high',
#        'nnm_severity of incident_low', 'nnm_severity of incident_medium',
#        'nnm_severity of incident_unknown',
# ...

# %%
data.columns = data.columns.str.replace(' ', '_')

# %%
data.columns
# Out:
# Index(['name_of_ship', 'first_event_of_ship', 'last_event_of_ship',
#        'life_time_of_ship_in_months', 'recency_of_first_event',
#        'recency_of_last_event', 'nlarp-total', 'nlarp_closure',
#        'nlarp_status_accepted', 'nlarp_status_open', 'nlarp_status_rejected',
#        'nlarp_category_safe_act', 'nlarp_category_unsafe_act',
#        'mlarp_accepted-safe_act', 'mlarp_accepted-safe_act-closure',
#        'mlarp_accepted-unsafe_act', 'mlarp_accepted-unsafe_act-closure',
#        'mlarp_open-safe_act', 'mlarp_open-unsafe_act',
#        'mlarp_rejected-safe_act', 'mlarp_rejected-safe_act-closure',
#        'mlarp_rejected-unsafe_act', 'mlarp_rejected-unsafe_act-closure',
#        'nnm-total', 'nnm_near_miss', 'nnm_report',
#        'nnm_investigation_commenced', 'nnm_investigation_completion',
#        'nnm_closure', 'nnm_severity_of_incident_high',
#        'nnm_severity_of_incident_low', 'nnm_severity_of_incident_medium',
#        'nnm_severity_of_incident_unknown',
# ...

# %%
data.columns = data.columns.str.replace('-', '_')

# %%
data.columns
# Out:
# Index(['name_of_ship', 'first_event_of_ship', 'last_event_of_ship',
#        'life_time_of_ship_in_months', 'recency_of_first_event',
#        'recency_of_last_event', 'nlarp_total', 'nlarp_closure',
#        'nlarp_status_accepted', 'nlarp_status_open', 'nlarp_status_rejected',
#        'nlarp_category_safe_act', 'nlarp_category_unsafe_act',
#        'mlarp_accepted_safe_act', 'mlarp_accepted_safe_act_closure',
#        'mlarp_accepted_unsafe_act', 'mlarp_accepted_unsafe_act_closure',
#        'mlarp_open_safe_act', 'mlarp_open_unsafe_act',
#        'mlarp_rejected_safe_act', 'mlarp_rejected_safe_act_closure',
#        'mlarp_rejected_unsafe_act', 'mlarp_rejected_unsafe_act_closure',
#        'nnm_total', 'nnm_near_miss', 'nnm_report',
#        'nnm_investigation_commenced', 'nnm_investigation_completion',
#        'nnm_closure', 'nnm_severity_of_incident_high',
#        'nnm_severity_of_incident_low', 'nnm_severity_of_incident_medium',
#        'nnm_severity_of_incident_unknown',
# ...

# %%
data.columns = data.columns.str.replace('__', '_')

# %%
data.columns
# Out:
# Index(['name_of_ship', 'first_event_of_ship', 'last_event_of_ship',
#        'life_time_of_ship_in_months', 'recency_of_first_event',
#        'recency_of_last_event', 'nlarp_total', 'nlarp_closure',
#        'nlarp_status_accepted', 'nlarp_status_open', 'nlarp_status_rejected',
#        'nlarp_category_safe_act', 'nlarp_category_unsafe_act',
#        'mlarp_accepted_safe_act', 'mlarp_accepted_safe_act_closure',
#        'mlarp_accepted_unsafe_act', 'mlarp_accepted_unsafe_act_closure',
#        'mlarp_open_safe_act', 'mlarp_open_unsafe_act',
#        'mlarp_rejected_safe_act', 'mlarp_rejected_safe_act_closure',
#        'mlarp_rejected_unsafe_act', 'mlarp_rejected_unsafe_act_closure',
#        'nnm_total', 'nnm_near_miss', 'nnm_report',
#        'nnm_investigation_commenced', 'nnm_investigation_completion',
#        'nnm_closure', 'nnm_severity_of_incident_high',
#        'nnm_severity_of_incident_low', 'nnm_severity_of_incident_medium',
#        'nnm_severity_of_incident_unknown',
# ...

# %%
data.columns = data.columns.str.strip()

# %%
data.columns
# Out:
# Index(['name_of_ship', 'first_event_of_ship', 'last_event_of_ship',
#        'life_time_of_ship_in_months', 'recency_of_first_event',
#        'recency_of_last_event', 'nlarp_total', 'nlarp_closure',
#        'nlarp_status_accepted', 'nlarp_status_open', 'nlarp_status_rejected',
#        'nlarp_category_safe_act', 'nlarp_category_unsafe_act',
#        'mlarp_accepted_safe_act', 'mlarp_accepted_safe_act_closure',
#        'mlarp_accepted_unsafe_act', 'mlarp_accepted_unsafe_act_closure',
#        'mlarp_open_safe_act', 'mlarp_open_unsafe_act',
#        'mlarp_rejected_safe_act', 'mlarp_rejected_safe_act_closure',
#        'mlarp_rejected_unsafe_act', 'mlarp_rejected_unsafe_act_closure',
#        'nnm_total', 'nnm_near_miss', 'nnm_report',
#        'nnm_investigation_commenced', 'nnm_investigation_completion',
#        'nnm_closure', 'nnm_severity_of_incident_high',
#        'nnm_severity_of_incident_low', 'nnm_severity_of_incident_medium',
#        'nnm_severity_of_incident_unknown',
# ...

# %%
data.columns = data.columns.str.replace('nnm', 'nm')
data.columns = data.columns.str.replace('nadi', 'adi')
data.columns = data.columns.str.replace('nlarp', 'larp')

# %%
data.columns
# Out:
# Index(['name_of_ship', 'first_event_of_ship', 'last_event_of_ship',
#        'life_time_of_ship_in_months', 'recency_of_first_event',
#        'recency_of_last_event', 'larp_total', 'larp_closure',
#        'larp_status_accepted', 'larp_status_open', 'larp_status_rejected',
#        'larp_category_safe_act', 'larp_category_unsafe_act',
#        'mlarp_accepted_safe_act', 'mlarp_accepted_safe_act_closure',
#        'mlarp_accepted_unsafe_act', 'mlarp_accepted_unsafe_act_closure',
#        'mlarp_open_safe_act', 'mlarp_open_unsafe_act',
#        'mlarp_rejected_safe_act', 'mlarp_rejected_safe_act_closure',
#        'mlarp_rejected_unsafe_act', 'mlarp_rejected_unsafe_act_closure',
#        'nm_total', 'nm_near_miss', 'nm_report', 'nm_investigation_commenced',
#        'nm_investigation_completion', 'nm_closure',
#        'nm_severity_of_incident_high', 'nm_severity_of_incident_low',
#        'nm_severity_of_incident_medium', 'nm_severity_of_incident_unknown',
# ...

# %%
data.columns = data.columns.str.replace('severity_of_incident', 'severity')
data.columns = data.columns.str.replace('probability_of_reoccurence', 'prob')
data.columns = data.columns.str.replace('incident_category_potential', 'category')
data.columns = data.columns.str.replace('learning_potential', 'learning')

# %%
data.columns
# Out:
# Index(['name_of_ship', 'first_event_of_ship', 'last_event_of_ship',
#        'life_time_of_ship_in_months', 'recency_of_first_event',
#        'recency_of_last_event', 'larp_total', 'larp_closure',
#        'larp_status_accepted', 'larp_status_open', 'larp_status_rejected',
#        'larp_category_safe_act', 'larp_category_unsafe_act',
#        'mlarp_accepted_safe_act', 'mlarp_accepted_safe_act_closure',
#        'mlarp_accepted_unsafe_act', 'mlarp_accepted_unsafe_act_closure',
#        'mlarp_open_safe_act', 'mlarp_open_unsafe_act',
#        'mlarp_rejected_safe_act', 'mlarp_rejected_safe_act_closure',
#        'mlarp_rejected_unsafe_act', 'mlarp_rejected_unsafe_act_closure',
#        'nm_total', 'nm_near_miss', 'nm_report', 'nm_investigation_commenced',
#        'nm_investigation_completion', 'nm_closure', 'nm_severity_high',
#        'nm_severity_low', 'nm_severity_medium', 'nm_severity_unknown',
#        'nm_prob_likely_high_medium_moderate', 'nm_prob_others',
# ...

# %%
data = data.rename(columns={
    'name_of_ship': 'ship_name',
    'first_event_of_ship': 'first_event',
    'last_event_of_ship': 'last_event',
    'life_time_of_ship_in_months': 'lifetime_months'
})

# %%
data.columns
# Out:
# Index(['ship_name', 'first_event', 'last_event', 'lifetime_months',
#        'recency_of_first_event', 'recency_of_last_event', 'larp_total',
#        'larp_closure', 'larp_status_accepted', 'larp_status_open',
#        'larp_status_rejected', 'larp_category_safe_act',
#        'larp_category_unsafe_act', 'mlarp_accepted_safe_act',
#        'mlarp_accepted_safe_act_closure', 'mlarp_accepted_unsafe_act',
#        'mlarp_accepted_unsafe_act_closure', 'mlarp_open_safe_act',
#        'mlarp_open_unsafe_act', 'mlarp_rejected_safe_act',
#        'mlarp_rejected_safe_act_closure', 'mlarp_rejected_unsafe_act',
#        'mlarp_rejected_unsafe_act_closure', 'nm_total', 'nm_near_miss',
#        'nm_report', 'nm_investigation_commenced',
#        'nm_investigation_completion', 'nm_closure', 'nm_severity_high',
#        'nm_severity_low', 'nm_severity_medium', 'nm_severity_unknown',
#        'nm_prob_likely_high_medium_moderate', 'nm_prob_others',
# ...

# %%
len(data.columns)
# Out:
# 96

# %%
data['adi_closure']
# Out:
# 0      4.0
# 1      4.0
# 2      1.0
# 3      6.0
# 4      5.0
#       ...
# 324    NaN
# 325    5.0
# 326    3.0
# 327    6.0
# 328    NaN
# Name: adi_closure, Length: 329, dtype: float64

# %%
data['adi_closure'].value_counts()
# Out:
# adi_closure
# 1.0     57
# 4.0     29
# 3.0     29
# 2.0     27
# 5.0     18
# 7.0     16
# 6.0     12
# 8.0     10
# 12.0    10
# 13.0     8
# 10.0     6
# 9.0      6
# 11.0     5
# 16.0     3
# 14.0     2
# 19.0     1
# 17.0     1
# 15.0     1
# 18.0     1
# Name: count, dtype: int64

# %%
data['adi_closure'].isna().sum()
# Out:
# np.int64(87)

# %%
data['adi_incident_category_catastrophic_or_extremely_harmful']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 324   NaN
# 325   NaN
# 326   NaN
# 327   NaN
# 328   NaN
# Name: adi_incident_category_catastrophic_or_extremely_harmful, Length: 329, dtype: float64

# %%
data['adi_incident_category_catastrophic_or_extremely_harmful'].value_counts()
# Out:
# adi_incident_category_catastrophic_or_extremely_harmful
# 1.0    10
# 2.0     2
# Name: count, dtype: int64

# %%
data['adi_incident_category_critical_or_severe_harm']
# Out:
# 0      NaN
# 1      1.0
# 2      NaN
# 3      2.0
# 4      NaN
#       ...
# 324    NaN
# 325    NaN
# 326    NaN
# 327    NaN
# 328    NaN
# Name: adi_incident_category_critical_or_severe_harm, Length: 329, dtype: float64

# %%
data['adi_incident_category_critical_or_severe_harm'].isna().sum()
# Out:
# np.int64(293)

# %%
data['adi_incident_category_critical_potential__near_miss']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 324   NaN
# 325   NaN
# 326   NaN
# 327   NaN
# 328   NaN
# Name: adi_incident_category_critical_potential__near_miss, Length: 329, dtype: float64

# %%
data['adi_incident_category_critical_potential__near_miss'].isna().sum()
# Out:
# np.int64(328)

# %%
data['adi_incident_category_marginal_or_moderate_harm']
# Out:
# 0      1.0
# 1      2.0
# 2      NaN
# 3      1.0
# 4      3.0
#       ...
# 324    NaN
# 325    2.0
# 326    NaN
# 327    3.0
# 328    NaN
# Name: adi_incident_category_marginal_or_moderate_harm, Length: 329, dtype: float64

# %%
data['adi_incident_category_marginal_or_moderate_harm'].value_counts()
# Out:
# adi_incident_category_marginal_or_moderate_harm
# 1.0     64
# 2.0     43
# 3.0     38
# 4.0     17
# 5.0      6
# 6.0      5
# 9.0      4
# 10.0     1
# 7.0      1
# Name: count, dtype: int64

# %%
data['adi_incident_category_marginal_or_moderate_harm'].isna().sum()
# Out:
# np.int64(150)

# %%
data['adi_incident_category_minor']
# Out:
# 0      3.0
# 1      3.0
# 2      1.0
# 3      5.0
# 4      4.0
#       ...
# 324    NaN
# 325    3.0
# 326    3.0
# 327    4.0
# 328    NaN
# Name: adi_incident_category_minor, Length: 329, dtype: float64

# %%
data['adi_incident_category_minor'].isna().sum()
# Out:
# np.int64(99)

# %%
data['adi_injuryaccidentcategory_fatality']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 324   NaN
# 325   NaN
# 326   NaN
# 327   NaN
# 328   NaN
# Name: adi_injuryaccidentcategory_fatality, Length: 329, dtype: float64

# %%
data['adi_incident_category_minor']
# Out:
# 0      3.0
# 1      3.0
# 2      1.0
# 3      5.0
# 4      4.0
#       ...
# 324    NaN
# 325    3.0
# 326    3.0
# 327    4.0
# 328    NaN
# Name: adi_incident_category_minor, Length: 329, dtype: float64

# %%
data['adi_injuryaccidentcategory_fatality'].isna().sum()
# Out:
# np.int64(295)

# %%
data['adi_injuryaccidentcategory_first_aid_case']
# Out:
# 0      1.0
# 1      2.0
# 2      NaN
# 3      2.0
# 4      NaN
#       ...
# 324    NaN
# 325    1.0
# 326    NaN
# 327    1.0
# 328    NaN
# Name: adi_injuryaccidentcategory_first_aid_case, Length: 329, dtype: float64

# %%
data['adi_injuryaccidentcategory_first_aid_case'].isna().sum()
# Out:
# np.int64(196)

# %%
data.describe()
# Out:
#        lifetime_months  recency_of_first_event  recency_of_last_event  \
# count       329.000000              329.000000             329.000000
# mean         27.367363               48.027649               9.472193
# std          19.948938               21.769824              15.890022
# min           0.032855                0.000000               0.000000
# 25%          10.086449               27.335264               1.117066
# 50%          22.308466               46.128257               1.938438
# 75%          45.076901               69.093821               6.143863
# max          70.933695               83.057147              69.028111
#
#         larp_total  larp_closure  larp_status_accepted  larp_status_open  \
# count   274.000000     86.000000            253.000000         52.000000
# mean    219.284672     65.197674            225.924901         49.134615
# std     205.723914    109.356279            207.202029         70.748388
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 329 entries, 0 to 328
# Data columns (total 96 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   ship_name                                                 329 non-null    str
#  1   first_event                                               329 non-null    str
#  2   last_event                                                329 non-null    str
#  3   lifetime_months                                           329 non-null    float64
#  4   recency_of_first_event                                    329 non-null    float64
#  5   recency_of_last_event                                     329 non-null    float64
#  6   larp_total                                                274 non-null    float64
#  7   larp_closure                                              86 non-null     float64
# ...

# %%
data['adi_injuryaccidentcategory_lost_workday_case']
# Out:
# 0      1.0
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 324    NaN
# 325    NaN
# 326    1.0
# 327    NaN
# 328    NaN
# Name: adi_injuryaccidentcategory_lost_workday_case, Length: 329, dtype: float64

# %%
data['adi_injuryaccidentcategory_lost_workday_case'].isna().sum()
# Out:
# np.int64(260)

# %%
data['adi_injuryaccidentcategory_medical_treatment_case']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 324    NaN
# 325    NaN
# 326    NaN
# 327    5.0
# 328    NaN
# Name: adi_injuryaccidentcategory_medical_treatment_case, Length: 329, dtype: float64

# %%
data['adi_injuryaccidentcategory_medical_treatment_case'].isna().sum()
# Out:
# np.int64(245)

# %%
data['adi_injuryaccidentcategory_permanent_partial_disability']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 324   NaN
# 325   NaN
# 326   NaN
# 327   NaN
# 328   NaN
# Name: adi_injuryaccidentcategory_permanent_partial_disability, Length: 329, dtype: float64

# %%
data['adi_injuryaccidentcategory_medical_treatment_case']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 324    NaN
# 325    NaN
# 326    NaN
# 327    5.0
# 328    NaN
# Name: adi_injuryaccidentcategory_medical_treatment_case, Length: 329, dtype: float64

# %%
data['adi_injuryaccidentcategory_permanent_total_disability']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 324   NaN
# 325   NaN
# 326   NaN
# 327   NaN
# 328   NaN
# Name: adi_injuryaccidentcategory_permanent_total_disability, Length: 329, dtype: float64

# %%
data['adi_injuryaccidentcategory_permanent_partial_disability']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 324   NaN
# 325   NaN
# 326   NaN
# 327   NaN
# 328   NaN
# Name: adi_injuryaccidentcategory_permanent_partial_disability, Length: 329, dtype: float64

# %%
data['adi_injuryaccidentcategory_restricted_work_case']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 324   NaN
# 325   NaN
# 326   NaN
# 327   NaN
# 328   NaN
# Name: adi_injuryaccidentcategory_restricted_work_case, Length: 329, dtype: float64

# %%
data['adi_injuryaccidentcategory_unknown']
# Out:
# 0      2.0
# 1      4.0
# 2      1.0
# 3      6.0
# 4      7.0
#       ...
# 324    NaN
# 325    4.0
# 326    2.0
# 327    1.0
# 328    NaN
# Name: adi_injuryaccidentcategory_unknown, Length: 329, dtype: float64

# %%
data['adi_injuryaccidentcategory_unknown']
# Out:
# 0      2.0
# 1      4.0
# 2      1.0
# 3      6.0
# 4      7.0
#       ...
# 324    NaN
# 325    4.0
# 326    2.0
# 327    1.0
# 328    NaN
# Name: adi_injuryaccidentcategory_unknown, Length: 329, dtype: float64

# %%
data['adi_leariningpotential_high']
# Out:
# 0      NaN
# 1      1.0
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 324    NaN
# 325    NaN
# 326    NaN
# 327    NaN
# 328    NaN
# Name: adi_leariningpotential_high, Length: 329, dtype: float64

# %%
data['adi_leariningpotential_high'].isna().sum()
# Out:
# np.int64(294)

# %%
data['adi_leariningpotential_low']
# Out:
# 0      2.0
# 1      1.0
# 2      NaN
# 3      3.0
# 4      3.0
#       ...
# 324    NaN
# 325    2.0
# 326    2.0
# 327    6.0
# 328    NaN
# Name: adi_leariningpotential_low, Length: 329, dtype: float64

# %%
data['adi_leariningpotential_medium']
# Out:
# 0      2.0
# 1      1.0
# 2      NaN
# 3      2.0
# 4      NaN
#       ...
# 324    NaN
# 325    1.0
# 326    1.0
# 327    NaN
# 328    NaN
# Name: adi_leariningpotential_medium, Length: 329, dtype: float64

# %%
data['adi_leariningpotential_unknown']
# Out:
# 0      NaN
# 1      3.0
# 2      1.0
# 3      3.0
# 4      4.0
#       ...
# 324    NaN
# 325    2.0
# 326    NaN
# 327    1.0
# 328    NaN
# Name: adi_leariningpotential_unknown, Length: 329, dtype: float64

# %%
data['adi_occurrence']
# Out:
# 0      4.0
# 1      6.0
# 2      1.0
# 3      8.0
# 4      7.0
#       ...
# 324    NaN
# 325    5.0
# 326    3.0
# 327    7.0
# 328    NaN
# Name: adi_occurrence, Length: 329, dtype: float64

# %%
data['adi_possibility_recurrence_likely']
# Out:
# 0      1.0
# 1      2.0
# 2      NaN
# 3      2.0
# 4      2.0
#       ...
# 324    NaN
# 325    NaN
# 326    1.0
# 327    1.0
# 328    NaN
# Name: adi_possibility_recurrence_likely, Length: 329, dtype: float64

# %%
data['adi_possibility_recurrence_very_unlikely']
# Out:
# 0      2.0
# 1      1.0
# 2      NaN
# 3      1.0
# 4      NaN
#       ...
# 324    NaN
# 325    1.0
# 326    1.0
# 327    2.0
# 328    NaN
# Name: adi_possibility_recurrence_very_unlikely, Length: 329, dtype: float64

# %%
data.columns
# Out:
# Index(['ship_name', 'first_event', 'last_event', 'lifetime_months',
#        'recency_of_first_event', 'recency_of_last_event', 'larp_total',
#        'larp_closure', 'larp_status_accepted', 'larp_status_open',
#        'larp_status_rejected', 'larp_category_safe_act',
#        'larp_category_unsafe_act', 'mlarp_accepted_safe_act',
#        'mlarp_accepted_safe_act_closure', 'mlarp_accepted_unsafe_act',
#        'mlarp_accepted_unsafe_act_closure', 'mlarp_open_safe_act',
#        'mlarp_open_unsafe_act', 'mlarp_rejected_safe_act',
#        'mlarp_rejected_safe_act_closure', 'mlarp_rejected_unsafe_act',
#        'mlarp_rejected_unsafe_act_closure', 'nm_total', 'nm_near_miss',
#        'nm_report', 'nm_investigation_commenced',
#        'nm_investigation_completion', 'nm_closure', 'nm_severity_high',
#        'nm_severity_low', 'nm_severity_medium', 'nm_severity_unknown',
#        'nm_prob_likely_high_medium_moderate', 'nm_prob_others',
# ...

# %%
data.columns = data.columns.str.replace('learining', 'learning')
data.columns = data.columns.str.replace('severityofincident', 'severity')

# %%
data.columns = data.columns.str.replace('__', '_')

# %%
data.columns = data.columns.str.replace('recency_of_', 'recency_')
data.columns = data.columns.str.replace('prob_likely_high_medium_moderate', 'prob_likely')
data.columns = data.columns.str.replace('prob_unlikely_low_marginal', 'prob_unlikely')
data.columns = data.columns.str.replace('prob_very_likely_very_high', 'prob_very_likely')
data.columns = data.columns.str.replace('prob_very_unlikely_very_low', 'prob_very_unlikely')

# %%
data.columns = data.columns.str.replace(
    'adi_incident_category_catastrophic_or_extremely_harmful',
    'adi_cat_catastrophic'
)

data.columns = data.columns.str.replace(
    'adi_incident_category_critical_or_severe_harm',
    'adi_cat_critical'
)

data.columns = data.columns.str.replace(
    'adi_incident_category_marginal_or_moderate_harm',
    'adi_cat_marginal'
)

# %%
data = data.rename(columns={
    'mlarp': 'larp_metric',
    'mnm': 'nm_metric',
    'madi': 'adi_metric',
    'ninc': 'incident_count',
    'ncs': 'case_count'
})

# %%
data.columns
# Out:
# Index(['ship_name', 'first_event', 'last_event', 'lifetime_months',
#        'recency_first_event', 'recency_last_event', 'larp_total',
#        'larp_closure', 'larp_status_accepted', 'larp_status_open',
#        'larp_status_rejected', 'larp_category_safe_act',
#        'larp_category_unsafe_act', 'mlarp_accepted_safe_act',
#        'mlarp_accepted_safe_act_closure', 'mlarp_accepted_unsafe_act',
#        'mlarp_accepted_unsafe_act_closure', 'mlarp_open_safe_act',
#        'mlarp_open_unsafe_act', 'mlarp_rejected_safe_act',
#        'mlarp_rejected_safe_act_closure', 'mlarp_rejected_unsafe_act',
#        'mlarp_rejected_unsafe_act_closure', 'nm_total', 'nm_near_miss',
#        'nm_report', 'nm_investigation_commenced',
#        'nm_investigation_completion', 'nm_closure', 'nm_severity_high',
#        'nm_severity_low', 'nm_severity_medium', 'nm_severity_unknown',
#        'nm_prob_likely', 'nm_prob_others', 'nm_prob_unlikely',
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 329 entries, 0 to 328
# Data columns (total 96 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   ship_name                                                 329 non-null    str
#  1   first_event                                               329 non-null    str
#  2   last_event                                                329 non-null    str
#  3   lifetime_months                                           329 non-null    float64
#  4   recency_first_event                                       329 non-null    float64
#  5   recency_last_event                                        329 non-null    float64
#  6   larp_total                                                274 non-null    float64
#  7   larp_closure                                              86 non-null     float64
# ...

# %%
data.isnull().sum().sort_values(ascending=False)
# Out:
# nm_investigation_completion                              328
# nm_investigation_commenced                               328
# adi_incident_category_critical_potential_near_miss       328
# adi_injuryaccidentcategory_permanent_total_disability    328
# nm_further_investigation_required_yes                    328
#                                                         ...
# recency_last_event                                         0
# last_event                                                 0
# lifetime_months                                            0
# incident_count                                             0
# case_count                                                 0
# Length: 96, dtype: int64

# %%
data['first_event'] = pd.to_datetime(data['first_event'], errors='coerce')
data['last_event'] = pd.to_datetime(data['last_event'], errors='coerce')

# %%
data['event_gap_days'] = (data['last_event'] - data['first_event']).dt.days

# %%
data.describe()
# Out:
#                       first_event                  last_event  \
# count                         329                         329
# mean   2017-06-03 19:28:37.933130  2019-09-14 16:42:18.601823
# min           2013-06-03 00:00:00         2014-09-28 00:00:00
# 25%           2015-09-13 00:00:00         2019-12-25 00:00:00
# 50%           2017-04-07 00:00:00         2020-05-01 00:00:00
# 75%           2019-03-07 00:00:00         2020-05-26 00:00:00
# max           2020-05-05 00:00:00         2020-06-29 00:00:00
# std                           NaN                         NaN
#
#        lifetime_months  recency_first_event  recency_last_event   larp_total  \
# count       329.000000           329.000000          329.000000   274.000000
# mean         27.367363            48.027649            9.472193   219.284672
# min           0.032855             0.000000            0.000000     1.000000
# 25%          10.086449            27.335264            1.117066    46.250000
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
sns.heatmap(data.corr(numeric_only=True), cmap='coolwarm')
plt.show()

# %%
data.groupby('ship_name')['nm_total'].sum().sort_values(ascending=False).head(10)
# Out:
# ship_name
# KM HAKATA         213.0
# SABARIMALA GAS    169.0
# SRI VISHNU        152.0
# FUJI GAS          149.0
# TIRUMALA GAS      124.0
# OCCITAN KEY       121.0
# PALANIMALA GAS    112.0
# SEROJA ENAM       105.0
# TAKAO GAS         103.0
# NANYANG STAR      102.0
# Name: nm_total, dtype: float64
