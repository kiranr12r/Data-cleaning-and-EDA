# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/home/kiran/Downloads/cleaned-data/LARPDatabase.csv")

# %%
data
# Out:
#        Unnamed: 0        MANAGEMENT          VESSEL             REF NO  \
# 0               0    SMPL - Chennai    NANYANG STAR    LR/NAST/2018/98
# 1               1    SMPL - Chennai      DEE4 BIRCH   LR/FRHA/2018/152
# 2               2    SMPL - Chennai    NANYANG STAR   LR/NAST/2018/153
# 3               3    SMPL - Chennai  VELOS SAPPHIRE  LR/GRVIC/2015/106
# 4               7  SMSL - Singapore         BENFICA     LR/BNFC/2018/3
# ...           ...               ...             ...                ...
# 61068      125824  SMSL - Singapore    BULK HOLLAND   LR/BUHD/2018/126
# 61069      125825    SMPL - Chennai      GAS STELLA    LR/STGS/2018/81
# 61070      125826    SMPL - Chennai     APL FLORIDA    LR/AFLO/2019/85
# 61071      125827    SMPL - Chennai      DEE4 CEDAR   LR/ORST/2018/283
# 61072      125828    SMPL - Chennai         CASTARA    LR/CAST/2019/47
#
#                OCCURRENCE DATE    Status  \
# 0      2018-04-22 03:05:14.000  Accepted
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'MANAGEMENT', 'VESSEL', 'REF NO', 'OCCURRENCE DATE',
#        'Status', 'AREA OF CONCERN', 'DESCRIPTION', 'IMMEDIATE ACTION TAKEN',
#        'Category', 'WORK EQUIPMENT', 'LARP PROCEDURE', 'LARP SAFETY DEVICE',
#        'WORK ENVIRONMENT', 'HOUSE KEEPING', 'PERMIT TO WORK', 'LARP PPE',
#        'WORK POSITION', 'REPORTED BY', 'CLOSURE REMARK', 'CLOSURE DATE',
#        'CLOSED BY'],
#       dtype='str')

# %%
data['Unnamed: 0']
# Out:
# 0             0
# 1             1
# 2             2
# 3             3
# 4             7
#           ...
# 61068    125824
# 61069    125825
# 61070    125826
# 61071    125827
# 61072    125828
# Name: Unnamed: 0, Length: 61073, dtype: int64

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'MANAGEMENT', 'VESSEL', 'REF NO', 'OCCURRENCE DATE',
#        'Status', 'AREA OF CONCERN', 'DESCRIPTION', 'IMMEDIATE ACTION TAKEN',
#        'Category', 'WORK EQUIPMENT', 'LARP PROCEDURE', 'LARP SAFETY DEVICE',
#        'WORK ENVIRONMENT', 'HOUSE KEEPING', 'PERMIT TO WORK', 'LARP PPE',
#        'WORK POSITION', 'REPORTED BY', 'CLOSURE REMARK', 'CLOSURE DATE',
#        'CLOSED BY'],
#       dtype='str')

# %%
print(data['MANAGEMENT'].is_unique)
# Out:
# False

# %%
data['MANAGEMENT'].duplicated().sum()
# Out:
# np.int64(61068)

# %%
data[data['MANAGEMENT'].duplicated()]
# Out:
#        Unnamed: 0        MANAGEMENT          VESSEL             REF NO  \
# 1               1    SMPL - Chennai      DEE4 BIRCH   LR/FRHA/2018/152
# 2               2    SMPL - Chennai    NANYANG STAR   LR/NAST/2018/153
# 3               3    SMPL - Chennai  VELOS SAPPHIRE  LR/GRVIC/2015/106
# 5               8    SMPL - Chennai  VELOS SAPPHIRE   LR/GRIV/2017/119
# 6               9  SMSL - Singapore       KM HAKATA    LR/HAKA/2017/10
# ...           ...               ...             ...                ...
# 61068      125824  SMSL - Singapore    BULK HOLLAND   LR/BUHD/2018/126
# 61069      125825    SMPL - Chennai      GAS STELLA    LR/STGS/2018/81
# 61070      125826    SMPL - Chennai     APL FLORIDA    LR/AFLO/2019/85
# 61071      125827    SMPL - Chennai      DEE4 CEDAR   LR/ORST/2018/283
# 61072      125828    SMPL - Chennai         CASTARA    LR/CAST/2019/47
#
#                OCCURRENCE DATE    Status  \
# 1      2018-08-18 09:21:47.000  Accepted
# ...

# %%
data.shape
# Out:
# (61073, 22)

# %%
data['MANAGEMENT'].nunique()
# Out:
# 4

# %%
data['MANAGEMENT'].value_counts()
# Out:
# MANAGEMENT
# SMPL - Chennai      42373
# SMSL - Singapore     9071
# SNSPL - Pune         5029
# SOS - Kochi          3634
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

data['MANAGEMENT'].value_counts().plot(kind='bar')

plt.title("Management Distribution")
plt.xlabel("Management")
plt.ylabel("Number of Records")
plt.show()

# %%
data['MANAGEMENT'].value_counts(normalize=True) * 100
# Out:
# MANAGEMENT
# SMPL - Chennai      70.495949
# SMSL - Singapore    15.091420
# SNSPL - Pune         8.366746
# SOS - Kochi          6.045885
# Name: proportion, dtype: float64

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'MANAGEMENT', 'VESSEL', 'REF NO', 'OCCURRENCE DATE',
#        'Status', 'AREA OF CONCERN', 'DESCRIPTION', 'IMMEDIATE ACTION TAKEN',
#        'Category', 'WORK EQUIPMENT', 'LARP PROCEDURE', 'LARP SAFETY DEVICE',
#        'WORK ENVIRONMENT', 'HOUSE KEEPING', 'PERMIT TO WORK', 'LARP PPE',
#        'WORK POSITION', 'REPORTED BY', 'CLOSURE REMARK', 'CLOSURE DATE',
#        'CLOSED BY'],
#       dtype='str')

# %%
data.head()
# Out:
#    Unnamed: 0        MANAGEMENT          VESSEL             REF NO  \
# 0           0    SMPL - Chennai    NANYANG STAR    LR/NAST/2018/98
# 1           1    SMPL - Chennai      DEE4 BIRCH   LR/FRHA/2018/152
# 2           2    SMPL - Chennai    NANYANG STAR   LR/NAST/2018/153
# 3           3    SMPL - Chennai  VELOS SAPPHIRE  LR/GRVIC/2015/106
# 4           7  SMSL - Singapore         BENFICA     LR/BNFC/2018/3
#
#            OCCURRENCE DATE    Status  \
# 0  2018-04-22 03:05:14.000  Accepted
# 1  2018-08-18 09:21:47.000  Accepted
# 2  2018-05-20 08:35:46.000  Accepted
# 3  2015-12-07 09:54:27.000  Accepted
# 4  2018-01-16 10:45:21.000  Accepted
#
#                                      AREA OF CONCERN  \
# 0  Safety Management (LSA & FFA) and security - C...
# 1  Safety Management (LSA & FFA) and security - C...
# 2           General Appearance and condition - Ch 12
# 3  Safety Management (LSA & FFA) and security - C...
# 4  Safety Management (LSA & FFA) and security - C...
#
# ...

# %%
data.isna().sum()
# Out:
# Unnamed: 0                    0
# MANAGEMENT                  966
# VESSEL                      966
# REF NO                        0
# OCCURRENCE DATE               0
# Status                        0
# AREA OF CONCERN           21146
# DESCRIPTION                  17
# IMMEDIATE ACTION TAKEN     7756
# Category                      0
# WORK EQUIPMENT            54464
# LARP PROCEDURE            34381
# LARP SAFETY DEVICE        54359
# WORK ENVIRONMENT          56656
# HOUSE KEEPING             54597
# PERMIT TO WORK            60402
# LARP PPE                  52774
# WORK POSITION             53386
# REPORTED BY                8959
# CLOSURE REMARK            55472
# CLOSURE DATE              55466
# CLOSED BY                 55467
# dtype: int64

# %%
data['MANAGEMENT'] = data['MANAGEMENT'].fillna("Unknown")

# %%
data['AREA OF CONCERN'].value_counts()
# Out:
# AREA OF CONCERN
# Safety Management (LSA & FFA) and security - Ch 5 d. COWSP                                      9589
# Ch V/Safety Management- (Reporting- LARP, Near Misses, Incident Investigations and PSC etc.)    3225
# Ch I GENERAL INFORMATION                                                                        2186
# General Appearance and condition - Ch 12                                                        2075
# Ch V/Safety Management- (Safe Access)                                                           1546
#                                                                                                 ...
# Ch VIII/ Cargo & Ballast System- (Cargo compressor and Motor Room)-LPG                             3
# Ch VIII/ Cargo & Ballast System- (Crude oil washing)                                               3
# Ch VIII/ Cargo & Ballast System- (Pressure relief and venting system)-LPG                          2
# ...

# %%
data['AREA OF CONCERN'].value_counts().head(10).plot(kind='bar')

plt.title("Top 10 Areas of Concern")
plt.xlabel("Area of Concern")
plt.ylabel("Number of Incidents")
plt.show()

# %%
(data['AREA OF CONCERN'].value_counts(normalize=True) * 100).head(10)
# Out:
# AREA OF CONCERN
# Safety Management (LSA & FFA) and security - Ch 5 d. COWSP                                      24.016330
# Ch V/Safety Management- (Reporting- LARP, Near Misses, Incident Investigations and PSC etc.)     8.077241
# Ch I GENERAL INFORMATION                                                                         5.474992
# General Appearance and condition - Ch 12                                                         5.196984
# Ch V/Safety Management- (Safe Access)                                                            3.872067
# Ch V/Safety Management- (Risk assessment, PTW, Checklist & Isolation)                            3.574023
# Engine and Steering compartments - Ch 11                                                         3.120695
# Safety Management (LSA & FFA) and security - Ch 5 a. LSA                                         3.010494
# Safety Management (LSA & FFA) and security - Ch 5 b. FFA                                         2.146417
# ...

# %%
import seaborn as sns

table = pd.crosstab(data['AREA OF CONCERN'], data['Category'])

sns.heatmap(table.head(15))
# Out:
# <Axes: xlabel='Category', ylabel='AREA OF CONCERN'>

# %%
pd.crosstab(data['MANAGEMENT'], data['AREA OF CONCERN'])
# Out:
# AREA OF CONCERN   Cargo and ballast system - Ch 8 a. Plan  \
# MANAGEMENT
# SMPL - Chennai                                         46
# SMSL - Singapore                                       20
# SNSPL - Pune                                            3
# SOS - Kochi                                             1
#
# AREA OF CONCERN   Cargo and ballast system - Ch 8 b. Execution  \
# MANAGEMENT
# SMPL - Chennai                                             155
# SMSL - Singapore                                            78
# SNSPL - Pune                                                21
# SOS - Kochi                                                  1
#
# AREA OF CONCERN   Cargo and ballast system - Ch 8 c. Monitoring  \
# MANAGEMENT
# SMPL - Chennai                                              429
# SMSL - Singapore                                             96
# SNSPL - Pune                                                 26
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'MANAGEMENT', 'VESSEL', 'REF NO', 'OCCURRENCE DATE',
#        'Status', 'AREA OF CONCERN', 'DESCRIPTION', 'IMMEDIATE ACTION TAKEN',
#        'Category', 'WORK EQUIPMENT', 'LARP PROCEDURE', 'LARP SAFETY DEVICE',
#        'WORK ENVIRONMENT', 'HOUSE KEEPING', 'PERMIT TO WORK', 'LARP PPE',
#        'WORK POSITION', 'REPORTED BY', 'CLOSURE REMARK', 'CLOSURE DATE',
#        'CLOSED BY'],
#       dtype='str')

# %%
data.drop(columns = ['Unnamed: 0'] , inplace = True)

# %%
data.columns
# Out:
# Index(['MANAGEMENT', 'VESSEL', 'REF NO', 'OCCURRENCE DATE', 'Status',
#        'AREA OF CONCERN', 'DESCRIPTION', 'IMMEDIATE ACTION TAKEN', 'Category',
#        'WORK EQUIPMENT', 'LARP PROCEDURE', 'LARP SAFETY DEVICE',
#        'WORK ENVIRONMENT', 'HOUSE KEEPING', 'PERMIT TO WORK', 'LARP PPE',
#        'WORK POSITION', 'REPORTED BY', 'CLOSURE REMARK', 'CLOSURE DATE',
#        'CLOSED BY'],
#       dtype='str')

# %%
print(data['AREA OF CONCERN'].to_string())
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
data['Category'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Category'>

# %%
import seaborn as sns

table = pd.crosstab(data['MANAGEMENT'], data['Category'])
sns.heatmap(table)
# Out:
# <Axes: xlabel='Category', ylabel='MANAGEMENT'>

# %%
data['Category'].value_counts()
# Out:
# Category
# Unsafe act    48481
# Safe act      12592
# Name: count, dtype: int64

# %%
data.columns
# Out:
# Index(['MANAGEMENT', 'VESSEL', 'REF NO', 'OCCURRENCE DATE', 'Status',
#        'AREA OF CONCERN', 'DESCRIPTION', 'IMMEDIATE ACTION TAKEN', 'Category',
#        'WORK EQUIPMENT', 'LARP PROCEDURE', 'LARP SAFETY DEVICE',
#        'WORK ENVIRONMENT', 'HOUSE KEEPING', 'PERMIT TO WORK', 'LARP PPE',
#        'WORK POSITION', 'REPORTED BY', 'CLOSURE REMARK', 'CLOSURE DATE',
#        'CLOSED BY'],
#       dtype='str')

# %%
data['Category'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Category'>

# %%
data.isna().sum()
# Out:
# MANAGEMENT                    0
# VESSEL                      966
# REF NO                        0
# OCCURRENCE DATE               0
# Status                        0
# AREA OF CONCERN           21146
# DESCRIPTION                  17
# IMMEDIATE ACTION TAKEN     7756
# Category                      0
# WORK EQUIPMENT            54464
# LARP PROCEDURE            34381
# LARP SAFETY DEVICE        54359
# WORK ENVIRONMENT          56656
# HOUSE KEEPING             54597
# PERMIT TO WORK            60402
# LARP PPE                  52774
# WORK POSITION             53386
# REPORTED BY                8959
# CLOSURE REMARK            55472
# CLOSURE DATE              55466
# CLOSED BY                 55467
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.isna().sum()
# Out:
# MANAGEMENT                    0
# VESSEL                      966
# REF NO                        0
# OCCURRENCE DATE               0
# Status                        0
# AREA OF CONCERN           21146
# DESCRIPTION                  17
# IMMEDIATE ACTION TAKEN     7756
# Category                      0
# WORK EQUIPMENT            54464
# LARP PROCEDURE            34381
# LARP SAFETY DEVICE        54359
# WORK ENVIRONMENT          56656
# HOUSE KEEPING             54597
# PERMIT TO WORK            60402
# LARP PPE                  52774
# WORK POSITION             53386
# REPORTED BY                8959
# CLOSURE REMARK            55472
# CLOSURE DATE              55466
# CLOSED BY                 55467
# dtype: int64

# %%
data['Status'].value_counts()
# Out:
# Status
# Accepted    57181
# Open         3522
# Rejected      370
# Name: count, dtype: int64

# %%
(data['Status'].value_counts(normalize=True) * 100).round(2)
# Out:
# Status
# Accepted    93.63
# Open         5.77
# Rejected     0.61
# Name: proportion, dtype: float64

# %%
import matplotlib.pyplot as plt

data['Status'].value_counts().plot(kind='bar')

plt.title("Incident Status Distribution")
plt.xlabel("Status")
plt.ylabel("Number of Records")

plt.show()

# %%
pd.crosstab(data['Status'], data['Category'])
# Out:
# Category  Safe act  Unsafe act
# Status
# Accepted     11300       45881
# Open          1145        2377
# Rejected       147         223

# %%
open_cases = data[data['Status'] == 'Open']
open_cases.head()
# Out:
#         MANAGEMENT        VESSEL             REF NO          OCCURRENCE DATE  \
# 8   SMPL - Chennai  TRIDENT STAR  LR/TRIDE/2015/102  2015-05-07 07:56:27.000
# 13  SMPL - Chennai          ISIS  LR/MTISI/2015/118  2015-07-15 10:55:47.000
# 14  SMPL - Chennai          ISIS    LR/ISIS/2016/62  2016-02-20 23:25:32.000
# 17  SMPL - Chennai  TRIDENT STAR  LR/TRIDE/2015/120  2015-05-27 13:31:21.000
# 31  SMPL - Chennai  TRIDENT STAR  LR/TRIDE/2015/112  2015-05-30 10:23:40.000
#
#    Status AREA OF CONCERN                                        DESCRIPTION  \
# 8    Open             NaN       Operating levers were not latched after use.
# 13   Open             NaN  Observed welden pump discharge hose leaking wh...
# 14   Open             NaN  One of the  torch kept in deck shelter found i...
# 17   Open             NaN  Found One of the crew member not wearing Eye p...
# 31   Open             NaN  Ship personnel found handling Chemical without...
#
# ...

# %%
data['Category'].value_counts()
# Out:
# Category
# Unsafe act    48481
# Safe act      12592
# Name: count, dtype: int64

# %%
data.columns
# Out:
# Index(['MANAGEMENT', 'VESSEL', 'REF NO', 'OCCURRENCE DATE', 'Status',
#        'AREA OF CONCERN', 'DESCRIPTION', 'IMMEDIATE ACTION TAKEN', 'Category',
#        'WORK EQUIPMENT', 'LARP PROCEDURE', 'LARP SAFETY DEVICE',
#        'WORK ENVIRONMENT', 'HOUSE KEEPING', 'PERMIT TO WORK', 'LARP PPE',
#        'WORK POSITION', 'REPORTED BY', 'CLOSURE REMARK', 'CLOSURE DATE',
#        'CLOSED BY'],
#       dtype='str')

# %%
data['OCCURRENCE DATE'] = pd.to_datetime(data['OCCURRENCE DATE'], errors='coerce')

# %%
data['Year'] = data['OCCURRENCE DATE'].dt.year
data['Month'] = data['OCCURRENCE DATE'].dt.month

# %%
data['OCCURRENCE DATE'].dtype
# Out:
# dtype('<M8[us]')

# %%
data['Year'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='Year'>

# %%
data.shape
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 61073 entries, 0 to 61072
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   MANAGEMENT              61073 non-null  str
#  1   VESSEL                  60107 non-null  str
#  2   REF NO                  61073 non-null  str
#  3   OCCURRENCE DATE         61073 non-null  datetime64[us]
#  4   Status                  61073 non-null  str
#  5   AREA OF CONCERN         39927 non-null  str
#  6   DESCRIPTION             61056 non-null  str
#  7   IMMEDIATE ACTION TAKEN  53317 non-null  str
#  8   Category                61073 non-null  str
#  9   WORK EQUIPMENT          6609 non-null   str
#  10  LARP PROCEDURE          26692 non-null  str
#  11  LARP SAFETY DEVICE      6714 non-null   str
#  12  WORK ENVIRONMENT        4417 non-null   str
#  13  HOUSE KEEPING           6476 non-null   str
#  14  PERMIT TO WORK          671 non-null    str
# ...

# %%
data['Category'].value_counts()
# Out:
# Category
# Unsafe act    48481
# Safe act      12592
# Name: count, dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
pd.crosstab(data['MANAGEMENT'], data['Category'])
# Out:
# Category          Safe act  Unsafe act
# MANAGEMENT
# SMPL - Chennai        7492       34881
# SMSL - Singapore      2776        6295
# SNSPL - Pune           872        4157
# SOS - Kochi            964        2670
# Unknown                488         478

# %%
data.columns
# Out:
# Index(['MANAGEMENT', 'VESSEL', 'REF NO', 'OCCURRENCE DATE', 'Status',
#        'AREA OF CONCERN', 'DESCRIPTION', 'IMMEDIATE ACTION TAKEN', 'Category',
#        'WORK EQUIPMENT', 'LARP PROCEDURE', 'LARP SAFETY DEVICE',
#        'WORK ENVIRONMENT', 'HOUSE KEEPING', 'PERMIT TO WORK', 'LARP PPE',
#        'WORK POSITION', 'REPORTED BY', 'CLOSURE REMARK', 'CLOSURE DATE',
#        'CLOSED BY', 'Year', 'Month'],
#       dtype='str')

# %%
data['Category'].value_counts()
# Out:
# Category
# Unsafe act    48481
# Safe act      12592
# Name: count, dtype: int64

# %%
sns.displot(data['Category'])

# %%
numeric_data = data.select_dtypes(include='number')

correlation = numeric_data.corr()

sns.heatmap(correlation, annot=True)
# Out:
# <Axes: >

# %%
import seaborn as sns
import pandas as pd

table = pd.crosstab(data['MANAGEMENT'], data['Category'])

sns.heatmap(table, annot=True)
# Out:
# <Axes: xlabel='Category', ylabel='MANAGEMENT'>

# %%
data.columns
# Out:
# Index(['MANAGEMENT', 'VESSEL', 'REF NO', 'OCCURRENCE DATE', 'Status',
#        'AREA OF CONCERN', 'DESCRIPTION', 'IMMEDIATE ACTION TAKEN', 'Category',
#        'WORK EQUIPMENT', 'LARP PROCEDURE', 'LARP SAFETY DEVICE',
#        'WORK ENVIRONMENT', 'HOUSE KEEPING', 'PERMIT TO WORK', 'LARP PPE',
#        'WORK POSITION', 'REPORTED BY', 'CLOSURE REMARK', 'CLOSURE DATE',
#        'CLOSED BY', 'Year', 'Month'],
#       dtype='str')

# %%
data['REPORTED BY'].isna().sum()
# Out:
# np.int64(8959)

# %%
print(data['REPORTED BY'].value_counts())
# Out:
# REPORTED BY
# Neil Perez Galvadores             283
# Amit Kumar                        136
# Sumit Kumar                       128
# Abhishek Kumar                    121
# Cyril Angelo Pimentel Patricio    117
#                                  ...
# Mohan Ram Khilery                   1
# Santosh Kumar Singh                 1
# Hemant Namdev Mandvikar             1
# Vignesh Sanjeev                     1
# Tomas Leslie Catarina Pereira       1
# Name: count, Length: 6872, dtype: int64

# %%
data['REPORTED BY'].value_counts().head(10)
# Out:
# REPORTED BY
# Neil Perez Galvadores              283
# Amit Kumar                         136
# Sumit Kumar                        128
# Abhishek Kumar                     121
# Cyril Angelo Pimentel Patricio     117
# John Lerry Leodones Pajarillaga    114
# Anurag Sharma                      113
# Susai Antony Raj Arockia Samy       94
# Rahul Prasad                        92
# Athish Soman                        90
# Name: count, dtype: int64

# %%
pd.crosstab(data['REPORTED BY'], data['Category'])
# Out:
# Category                   Safe act  Unsafe act
# REPORTED BY
# Aadesh Jalan                      1          25
# Aaditya Aadarsh                   2           8
# Aakash Kailashamoorthi            0           8
# Aakash Sreenivasan                1           1
# Aakshhay Naaren Sharrma           1           3
# ...                             ...         ...
# Zoeb Mohammadhanif Shaikh         3           6
# Zosimo Pambo Hudieras             0           3
# Zosimojr Catalan Sionil           0           1
# Zubair Ahmad Siddiqui             1           3
# Zulfikar Ali                      0           2
#
# [6872 rows x 2 columns]

# %%
data.columns
# Out:
# Index(['MANAGEMENT', 'VESSEL', 'REF NO', 'OCCURRENCE DATE', 'Status',
#        'AREA OF CONCERN', 'DESCRIPTION', 'IMMEDIATE ACTION TAKEN', 'Category',
#        'WORK EQUIPMENT', 'LARP PROCEDURE', 'LARP SAFETY DEVICE',
#        'WORK ENVIRONMENT', 'HOUSE KEEPING', 'PERMIT TO WORK', 'LARP PPE',
#        'WORK POSITION', 'REPORTED BY', 'CLOSURE REMARK', 'CLOSURE DATE',
#        'CLOSED BY', 'Year', 'Month'],
#       dtype='str')

# %%
data['DESCRIPTION'][1]
# Out:
# 'EXPIRED FOOD IN ECR WAS FOUND BEING USED. IMMEDIATELY RENEWED THEM WITH FRESH FOOD ITEMS.'

# %%
data.columns
# Out:
# Index(['MANAGEMENT', 'VESSEL', 'REF NO', 'OCCURRENCE DATE', 'Status',
#        'AREA OF CONCERN', 'DESCRIPTION', 'IMMEDIATE ACTION TAKEN', 'Category',
#        'WORK EQUIPMENT', 'LARP PROCEDURE', 'LARP SAFETY DEVICE',
#        'WORK ENVIRONMENT', 'HOUSE KEEPING', 'PERMIT TO WORK', 'LARP PPE',
#        'WORK POSITION', 'REPORTED BY', 'CLOSURE REMARK', 'CLOSURE DATE',
#        'CLOSED BY', 'Year', 'Month'],
#       dtype='str')

# %%
data['Year']
# Out:
# 0        2018
# 1        2018
# 2        2018
# 3        2015
# 4        2018
#          ...
# 61068    2018
# 61069    2018
# 61070    2019
# 61071    2018
# 61072    2019
# Name: Year, Length: 61073, dtype: int32

# %%
data.columns
# Out:
# Index(['MANAGEMENT', 'VESSEL', 'REF NO', 'OCCURRENCE DATE', 'Status',
#        'AREA OF CONCERN', 'DESCRIPTION', 'IMMEDIATE ACTION TAKEN', 'Category',
#        'WORK EQUIPMENT', 'LARP PROCEDURE', 'LARP SAFETY DEVICE',
#        'WORK ENVIRONMENT', 'HOUSE KEEPING', 'PERMIT TO WORK', 'LARP PPE',
#        'WORK POSITION', 'REPORTED BY', 'CLOSURE REMARK', 'CLOSURE DATE',
#        'CLOSED BY', 'Year', 'Month'],
#       dtype='str')

# %%
data['CLOSED BY'].isna().sum()
# Out:
# np.int64(55467)

# %%
data = data.drop(columns=['CLOSED BY'])

# %%
data.columns
# Out:
# Index(['MANAGEMENT', 'VESSEL', 'REF NO', 'OCCURRENCE DATE', 'Status',
#        'AREA OF CONCERN', 'DESCRIPTION', 'IMMEDIATE ACTION TAKEN', 'Category',
#        'WORK EQUIPMENT', 'LARP PROCEDURE', 'LARP SAFETY DEVICE',
#        'WORK ENVIRONMENT', 'HOUSE KEEPING', 'PERMIT TO WORK', 'LARP PPE',
#        'WORK POSITION', 'REPORTED BY', 'CLOSURE REMARK', 'CLOSURE DATE',
#        'Year', 'Month'],
#       dtype='str')

# %%
data['AREA OF CONCERN'].value_counts()
# Out:
# AREA OF CONCERN
# Safety Management (LSA & FFA) and security - Ch 5 d. COWSP                                      9589
# Ch V/Safety Management- (Reporting- LARP, Near Misses, Incident Investigations and PSC etc.)    3225
# Ch I GENERAL INFORMATION                                                                        2186
# General Appearance and condition - Ch 12                                                        2075
# Ch V/Safety Management- (Safe Access)                                                           1546
#                                                                                                 ...
# Ch VIII/ Cargo & Ballast System- (Cargo compressor and Motor Room)-LPG                             3
# Ch VIII/ Cargo & Ballast System- (Crude oil washing)                                               3
# Ch VIII/ Cargo & Ballast System- (Pressure relief and venting system)-LPG                          2
# ...

# %%
data['CLOSURE DATE'].isna().sum()
# Out:
# np.int64(55466)

# %%
list(data.columns)
# Out:
# ['MANAGEMENT',
#  'VESSEL',
#  'REF NO',
#  'OCCURRENCE DATE',
#  'Status',
#  'AREA OF CONCERN',
#  'DESCRIPTION',
#  'IMMEDIATE ACTION TAKEN',
#  'Category',
#  'WORK EQUIPMENT',
#  'LARP PROCEDURE',
#  'LARP SAFETY DEVICE',
#  'WORK ENVIRONMENT',
#  'HOUSE KEEPING',
#  'PERMIT TO WORK',
#  'LARP PPE',
#  'WORK POSITION',
#  'REPORTED BY',
#  'CLOSURE REMARK',
#  'CLOSURE DATE',
#  'Year',
#  'Month']

# %%
data['LARP PPE'].isna().sum()
# Out:
# np.int64(52774)

# %%
data['LARP PPE'].value_counts()
# Out:
# LARP PPE
# Arms/Hands            2794
# Eye                   1464
# Inadequate            1099
# Head                  1087
# Inappropriate          615
# Leg/Feet               355
# Ears                   266
# Face                   193
# Defective              185
# Respiratory System     154
# Trunk                   85
# Truck                    2
# Name: count, dtype: int64

# %%
data['LARP PPE'] = data['LARP PPE'].replace('Truck', 'Trunk')

# %%
import matplotlib.pyplot as plt

data['LARP PPE'].value_counts().plot(kind='bar')

plt.title("PPE Related Safety Issues")
plt.xlabel("PPE Type")
plt.ylabel("Number of Incidents")
plt.show()

# %%
list(data.columns)
# Out:
# ['MANAGEMENT',
#  'VESSEL',
#  'REF NO',
#  'OCCURRENCE DATE',
#  'Status',
#  'AREA OF CONCERN',
#  'DESCRIPTION',
#  'IMMEDIATE ACTION TAKEN',
#  'Category',
#  'WORK EQUIPMENT',
#  'LARP PROCEDURE',
#  'LARP SAFETY DEVICE',
#  'WORK ENVIRONMENT',
#  'HOUSE KEEPING',
#  'PERMIT TO WORK',
#  'LARP PPE',
#  'WORK POSITION',
#  'REPORTED BY',
#  'CLOSURE REMARK',
#  'CLOSURE DATE',
#  'Year',
#  'Month']

# %%
data.isna().sum()
# Out:
# MANAGEMENT                    0
# VESSEL                      966
# REF NO                        0
# OCCURRENCE DATE               0
# Status                        0
# AREA OF CONCERN           21146
# DESCRIPTION                  17
# IMMEDIATE ACTION TAKEN     7756
# Category                      0
# WORK EQUIPMENT            54464
# LARP PROCEDURE            34381
# LARP SAFETY DEVICE        54359
# WORK ENVIRONMENT          56656
# HOUSE KEEPING             54597
# PERMIT TO WORK            60402
# LARP PPE                  52774
# WORK POSITION             53386
# REPORTED BY                8959
# CLOSURE REMARK            55472
# CLOSURE DATE              55466
# Year                          0
# Month                         0
# dtype: int64

# %%
data['REPORTED BY'].value_counts()
# Out:
# REPORTED BY
# Neil Perez Galvadores             283
# Amit Kumar                        136
# Sumit Kumar                       128
# Abhishek Kumar                    121
# Cyril Angelo Pimentel Patricio    117
#                                  ...
# Mohan Ram Khilery                   1
# Santosh Kumar Singh                 1
# Hemant Namdev Mandvikar             1
# Vignesh Sanjeev                     1
# Tomas Leslie Catarina Pereira       1
# Name: count, Length: 6872, dtype: int64

# %%
data['REPORTED BY'].value_counts().head(10)
# Out:
# REPORTED BY
# Neil Perez Galvadores              283
# Amit Kumar                         136
# Sumit Kumar                        128
# Abhishek Kumar                     121
# Cyril Angelo Pimentel Patricio     117
# John Lerry Leodones Pajarillaga    114
# Anurag Sharma                      113
# Susai Antony Raj Arockia Samy       94
# Rahul Prasad                        92
# Athish Soman                        90
# Name: count, dtype: int64

# %%
data['REPORTED BY'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='REPORTED BY'>

# %%
data.columns
# Out:
# Index(['MANAGEMENT', 'VESSEL', 'REF NO', 'OCCURRENCE DATE', 'Status',
#        'AREA OF CONCERN', 'DESCRIPTION', 'IMMEDIATE ACTION TAKEN', 'Category',
#        'WORK EQUIPMENT', 'LARP PROCEDURE', 'LARP SAFETY DEVICE',
#        'WORK ENVIRONMENT', 'HOUSE KEEPING', 'PERMIT TO WORK', 'LARP PPE',
#        'WORK POSITION', 'REPORTED BY', 'CLOSURE REMARK', 'CLOSURE DATE',
#        'Year', 'Month'],
#       dtype='str')

# %%
data['Status'].value_counts()
# Out:
# Status
# Accepted    57181
# Open         3522
# Rejected      370
# Name: count, dtype: int64

# %%
data.columns
# Out:
# Index(['MANAGEMENT', 'VESSEL', 'REF NO', 'OCCURRENCE DATE', 'Status',
#        'AREA OF CONCERN', 'DESCRIPTION', 'IMMEDIATE ACTION TAKEN', 'Category',
#        'WORK EQUIPMENT', 'LARP PROCEDURE', 'LARP SAFETY DEVICE',
#        'WORK ENVIRONMENT', 'HOUSE KEEPING', 'PERMIT TO WORK', 'LARP PPE',
#        'WORK POSITION', 'REPORTED BY', 'CLOSURE REMARK', 'CLOSURE DATE',
#        'Year', 'Month'],
#       dtype='str')

# %%
data['HOUSE KEEPING'].isna().sum()
# Out:
# np.int64(54597)

# %%
data.columns
# Out:
# Index(['MANAGEMENT', 'VESSEL', 'REF NO', 'OCCURRENCE DATE', 'Status',
#        'AREA OF CONCERN', 'DESCRIPTION', 'IMMEDIATE ACTION TAKEN', 'Category',
#        'WORK EQUIPMENT', 'LARP PROCEDURE', 'LARP SAFETY DEVICE',
#        'WORK ENVIRONMENT', 'HOUSE KEEPING', 'PERMIT TO WORK', 'LARP PPE',
#        'WORK POSITION', 'REPORTED BY', 'CLOSURE REMARK', 'CLOSURE DATE',
#        'Year', 'Month'],
#       dtype='str')

# %%
data['PERMIT TO WORK'].value_counts()
# Out:
# PERMIT TO WORK
# Risk assessment not prepared    290
# Permit not issued               155
# Isolation not carried out       123
# Isolation Ineffective            82
# Permit not closed correctly      21
# Name: count, dtype: int64

# %%
data.columns
# Out:
# Index(['MANAGEMENT', 'VESSEL', 'REF NO', 'OCCURRENCE DATE', 'Status',
#        'AREA OF CONCERN', 'DESCRIPTION', 'IMMEDIATE ACTION TAKEN', 'Category',
#        'WORK EQUIPMENT', 'LARP PROCEDURE', 'LARP SAFETY DEVICE',
#        'WORK ENVIRONMENT', 'HOUSE KEEPING', 'PERMIT TO WORK', 'LARP PPE',
#        'WORK POSITION', 'REPORTED BY', 'CLOSURE REMARK', 'CLOSURE DATE',
#        'Year', 'Month'],
#       dtype='str')

# %%
data['LARP PPE'].isna().sum()
# Out:
# np.int64(52774)

# %%
data.columns
# Out:
# Index(['MANAGEMENT', 'VESSEL', 'REF NO', 'OCCURRENCE DATE', 'Status',
#        'AREA OF CONCERN', 'DESCRIPTION', 'IMMEDIATE ACTION TAKEN', 'Category',
#        'WORK EQUIPMENT', 'LARP PROCEDURE', 'LARP SAFETY DEVICE',
#        'WORK ENVIRONMENT', 'HOUSE KEEPING', 'PERMIT TO WORK', 'LARP PPE',
#        'WORK POSITION', 'REPORTED BY', 'CLOSURE REMARK', 'CLOSURE DATE',
#        'Year', 'Month'],
#       dtype='str')
