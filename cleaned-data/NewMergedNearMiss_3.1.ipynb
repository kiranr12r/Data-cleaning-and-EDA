# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv('/home/kiran/Downloads/cleaned-data/Raw-Data/NewMergedNearMiss_3.1.csv')

# %%
data
# Out:
#           NME ID             Ref.No.    Name of Ship Type of Ship  \
# 0      NME100000         CAL-01/2012  APL CALIFORNIA    CONTAINER
# 1      NME100001         CHI-01/2012        TS CHINA    CONTAINER
# 2      NME100002         CHI-02/2012        TS CHINA    CONTAINER
# 3      NME100003         FLD-01-2012     APL FLORIDA    CONTAINER
# 4      NME100004          CAP-001/12   CALA PINGUINO    CONTAINER
# ...          ...                 ...             ...          ...
# 12441  NME112441  NM/NBAL/2020/Apr/4     NORD BALTIC          NAN
# 12442  NME112442  NM/NSFX/2020/Apr/6    NAVIOS FELIX          NAN
# 12443  NME112443  NM/VOLN/2020/Apr/7         VOLANTE          NAN
# 12444  NME112444  NM/HOUM/2020/Apr/8     HOURAI MARU          NAN
# 12445  NME112445  NM/LORD/2020/May/3         BW LORD          NAN
#
#                 Date of Report  Delay (in days)  \
# 0                   2012-01-03              0.0
# 1                   2012-01-05              0.0
# ...

# %%
data.columns
# Out:
# Index(['NME ID', 'Ref.No.', 'Name of Ship', 'Type of Ship', 'Date of Report',
#        'Delay (in days)', 'Description of the incident and cause analysis',
#        'Location', 'Probability of Reoccurence', 'Cause Analysis',
#        'Counter measure to prevent recurrence',
#        'Suggested Corrective Action (Office Use)',
#        'Date Corrective action completed', 'Area of Concern',
#        'Date Investigation Commenced', 'Target Date',
#        'Date of Investigation Completion', 'Extension (if any) with remarks',
#        'Time Period (in days)', 'Status', 'Master', 'Chief Engineer',
#        'Superintendent', 'Details of potential loss Category',
#        'Date of Near Miss', 'year', 'PIC', 'Port Name', 'Related Department',
#        'Description of event leading to the incident',
#        'Immediate action taken', 'Potential extent of damage/injury',
#        'Potential Damage category', 'Potential Damage subcategory',
# ...

# %%
data
# Out:
#           NME ID             Ref.No.    Name of Ship Type of Ship  \
# 0      NME100000         CAL-01/2012  APL CALIFORNIA    CONTAINER
# 1      NME100001         CHI-01/2012        TS CHINA    CONTAINER
# 2      NME100002         CHI-02/2012        TS CHINA    CONTAINER
# 3      NME100003         FLD-01-2012     APL FLORIDA    CONTAINER
# 4      NME100004          CAP-001/12   CALA PINGUINO    CONTAINER
# ...          ...                 ...             ...          ...
# 12441  NME112441  NM/NBAL/2020/Apr/4     NORD BALTIC          NAN
# 12442  NME112442  NM/NSFX/2020/Apr/6    NAVIOS FELIX          NAN
# 12443  NME112443  NM/VOLN/2020/Apr/7         VOLANTE          NAN
# 12444  NME112444  NM/HOUM/2020/Apr/8     HOURAI MARU          NAN
# 12445  NME112445  NM/LORD/2020/May/3         BW LORD          NAN
#
#                 Date of Report  Delay (in days)  \
# 0                   2012-01-03              0.0
# 1                   2012-01-05              0.0
# ...

# %%
data['Area of Concern']
# Out:
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                         Mooring
#                    ...
# 12441    Cargo And Ballast System
# 12442                         NaN
# 12443                         NaN
# 12444                     Mooring
# 12445           Safety Management
# Name: Area of Concern, Length: 12446, dtype: str

# %%
data['Area of Concern'].value_counts()
# Out:
# Area of Concern
# Safety Management                4112
# Engine & Steering Compartment    1216
# Mooring                          1052
# Cargo And Ballast System          802
# Navigation                        523
# General App & Condition           484
# Others                            453
# Cowsp                             212
# Crew Management                   172
# Environment                       129
# Company Documents                  87
# Communication                      75
# Planned Maintenance                25
# Monitoring                         23
# Execution & Monitoring             13
# Lack Of Procedure                   6
# Annexure 1 To Annexure 6            4
# Name: count, dtype: int64

# %%
data['Area of Concern'].isnull().sum()
# Out:
# np.int64(3058)

# %%
data['Cause Analysis']
# Out:
# 0        Suspect undeclared machinery stowed inside a c...
# 1        Failure to follow repair / maintenance instruc...
# 2        Failure to follow repair/maintenance instructi...
# 3        Prior arrival to Yokohama, vessel had very bad...
# 4        Duty Officer should always check the quality o...
#                                ...
# 12441                                                  NaN
# 12442                                                  NaN
# 12443                                                  NaN
# 12444                                                  NaN
# 12445                                                  NaN
# Name: Cause Analysis, Length: 12446, dtype: str

# %%
data['Cause Analysis'].isnull().sum()
# Out:
# np.int64(7510)

# %%
data['Chief Engineer'].value_counts()
# Out:
# Chief Engineer
# C/E.SelvaKumar                 46
# PRS Nair                       31
# Molano Alan                    26
# Jiby Joseph                    24
# Thirunavkkarasu chezhain       24
#                                ..
# Ruhul rai                       1
# Rahul                           1
# Mr James Martin                 1
# Gulshan Singh Ramkala Singh     1
# Felix B. Climaco                1
# Name: count, Length: 300, dtype: int64

# %%
data['Chief Engineer'].isna().sum()
# Out:
# np.int64(11406)

# %%
data['ClosingDate'].value_counts()
# Out:
# ClosingDate
# 2017-05-15 00:00:00    41
# 2019-08-13 00:00:00    40
# 2016-09-15 00:00:00    32
# 2019-05-20 00:00:00    31
# 2014-11-25 00:00:00    29
#                        ..
# 2020-05-21 00:00:00     1
# 2020-04-19 00:00:00     1
# 2020-03-11 00:00:00     1
# 2020-04-09 00:00:00     1
# 2020-05-27 00:00:00     1
# Name: count, Length: 1153, dtype: int64

# %%
data['ClosingDate'] = pd.to_datetime(data['ClosingDate']).dt.date

# %%
data['ClosingDate'].isna().sum()
# Out:
# np.int64(7084)

# %%
data['ClosingNote'].head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: ClosingNote, dtype: str

# %%
data['Closure Date - CA']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 12441    NaN
# 12442    NaN
# 12443    NaN
# 12444    NaN
# 12445    NaN
# Name: Closure Date - CA, Length: 12446, dtype: str

# %%
data['Closure Date - CA'].isna().sum()
# Out:
# np.int64(12191)

# %%
data['Corrective Action'].head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: Corrective Action, dtype: str

# %%
data['Corrective Action'].isna().sum()
# Out:
# np.int64(9634)

# %%
data['Counter measure to prevent recurrence'].head()
# Out:
# 0    1. All cargo holds to be inspected throughly o...
# 1    All duty engineers and duty oilers instruct to...
# 2    Notice Being Posted near all A/E's that " Star...
# 3    After heavy weather all LSA-FFA fittings to be...
# 4    All crew atfwd&aft station to be positioned we...
# Name: Counter measure to prevent recurrence, dtype: str

# %%
data['Date Corrective action completed'].head()
# Out:
# 0                28/5/12
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4    2012-05-21 00:00:00
# Name: Date Corrective action completed, dtype: str

# %%
data['Date Corrective action completed'].value_counts()
# Out:
# Date Corrective action completed
# 2013-08-13 00:00:00    26
# 2013-08-14 00:00:00    20
# 2013-09-18 00:00:00    19
# 2012-05-25 00:00:00    18
# 2013-10-14 00:00:00    18
#                        ..
# 10-01-2015              1
# 21-11-2014              1
# 04-08-2014              1
# 23-07-2014              1
# 18-08-2014              1
# Name: count, Length: 305, dtype: int64

# %%
data['Date Corrective action completed'] = pd.to_datetime(
    data['Date Corrective action completed'],
    errors='coerce',
    dayfirst=True
)
# Out:
# /tmp/ipykernel_4517/4054992174.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['Date Corrective action completed'] = pd.to_datetime(

# %%
data['Date Corrective action completed'] = data['Date Corrective action completed'].dt.date

# %%
data['Date Corrective action completed'].value_counts()
# Out:
# Date Corrective action completed
# 2013-08-13    26
# 2013-08-14    20
# 2013-09-18    19
# 2012-05-25    18
# 2013-10-14    18
#               ..
# 2015-01-10     1
# 2014-11-21     1
# 2014-08-04     1
# 2014-07-23     1
# 2014-08-18     1
# Name: count, Length: 287, dtype: int64

# %%
data['year'] = pd.to_datetime(data['Date Corrective action completed']).dt.year
data['month'] = pd.to_datetime(data['Date Corrective action completed']).dt.month

# %%
data['Date Investigation Commenced']
# Out:
# 0        2012-01-03
# 1        2012-01-05
# 2        2012-01-05
# 3        2012-01-10
# 4               NaN
#             ...
# 12441           NaN
# 12442           NaN
# 12443           NaN
# 12444           NaN
# 12445           NaN
# Name: Date Investigation Commenced, Length: 12446, dtype: str

# %%
data['Date Investigation Commenced'].isna().sum()
# Out:
# np.int64(11463)

# %%
data['Date of Investigation Completion'].isna().sum()
# Out:
# np.int64(11357)

# %%
data['Date of Near Miss'].isna().sum()
# Out:
# np.int64(2)

# %%
data['Date of Near Miss']
# Out:
# 0        2012-01-03
# 1        2012-01-05
# 2        2012-01-06
# 3        2012-01-07
# 4        2012-01-07
#             ...
# 12441    2020-04-04
# 12442    2020-04-21
# 12443    2020-04-29
# 12444    2020-04-23
# 12445    2020-04-29
# Name: Date of Near Miss, Length: 12446, dtype: str

# %%
data['Date of Report']
# Out:
# 0                     2012-01-03
# 1                     2012-01-05
# 2                     2012-01-06
# 3                     2012-01-09
# 4                     2012-01-23
#                   ...
# 12441    2020-04-12 17:43:37.050
# 12442    2020-04-21 06:22:51.907
# 12443    2020-04-30 12:20:24.683
# 12444    2020-04-24 13:43:40.970
# 12445    2020-05-02 17:40:18.397
# Name: Date of Report, Length: 12446, dtype: str

# %%
data['Date of Reporting'].isna().sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/myenv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date of Reporting'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 1
# ...

# %%
ss
